# %%
# %matplotlib notebook
#-----------------------------------------------------------------------------#
# Copyright (c) 2020 Institute of High Energy Physics Chinese Academy of 
#                    Science
#-----------------------------------------------------------------------------#

__authors__  = "Han Xu - HEPS Hard X-ray Scattering Beamline (B4)"
__date__     = "Date : 10.07.2020"
__version__  = "Alpha-2.0"


"""
plot: Plot the result. 

paper: "A Wave Optics Model for the Effect of Partial Coherence on Coherent 
        Diffractive Imaging"
        
fig1. the secondary source. Figure.2 of paper.
fig2. the intensity at the sample plane. Figure.7a of paper. 
    
Functions: none.
           
Classes  : none.    
"""

#-----------------------------------------------------------------------------#
# libaries

import pickle
import matplotlib.pyplot as plt
import numpy as np

#-----------------------------------------------------------------------------#
# plot secondary source

#secondary_source = pickle.load(open("secondary_source.pkl", 'rb'))
secondary_source = np.load("secondary_source.npz")

x = np.linspace(-30*0.5, 30*0.5, 61)
y = np.linspace(-15*0.5, 15*0.5, 31)
#intensity = secondary_source.intensity
intensity = secondary_source['intensity']

plt.figure(figsize = (6, 3))
plt.pcolor(x, y, intensity, cmap = 'jet') 
plt.colorbar()

#-----------------------------------------------------------------------------#
# plot sample plane

#sample_plane = pickle.load(open("sample_plane.pkl", 'rb'))
sample_plane = np.load("sample_plane.npz")

x = np.linspace(-64*0.1575, 64*0.1575, 129)
y = np.linspace(-64*0.1575, 64*0.1575, 129)
#intensity = sample_plane.intensity
intensity = sample_plane['intensity']

plt.figure(figsize = (5, 4))
plt.pcolor(x, y, intensity, cmap = 'jet') 
plt.colorbar()
# Out:
# <img src="data:image/png;base64,..." width="600">
# <ipython-input-7-bb9712dd6349>:45: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(x, y, intensity, cmap = 'jet')
# <img src="data:image/png;base64,..." width="500">
# <ipython-input-7-bb9712dd6349>:60: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   plt.pcolor(x, y, intensity, cmap = 'jet')
